# %%
n_in=int(1000)
m_in=int(1000)
M = (ctypes.c_double * (n_in * m_in))()
for i in range(n_in):
    for j in range(m_in):
        M[i*m_in+j] = abs(n_in-2*i + m_in-2*j-2)

# %%
import rasterio
import ctypes
import math
import numpy as np

# %%
#%%time 

file_path = "data/GHS_POP_E2030_GLOBE_R2023A_54009_100_V1_0_R5_C19.tif"

compression = 1000  # size of blocks

with rasterio.open(file_path) as src:
    n_in, m_in = src.height, src.width
    n = math.ceil(n_in / compression)
    m = math.ceil(m_in / compression)
print(n_in,m_in)
# create the ctypes array
G = (ctypes.c_double * (n * m))()
for k in range(n * m):
    G[k] = 0.0

with rasterio.open(file_path) as src:
    for i in range(n):
        for j in range(m):
            # compute actual window bounds
            row_start = i * compression
            row_stop  = min((i + 1) * compression, n_in)
            col_start = j * compression
            col_stop  = min((j + 1) * compression, m_in)

            window = ((row_start, row_stop), (col_start, col_stop))
            block = src.read(int(1), window=window).astype('float64')
            if src.nodata is not None:
                block = np.where(block == src.nodata, np.nan, block)
            if np.isnan(block).all():
                block_mean = 0.0  # or np.nan, depending on your use case
            else:
                block_mean = np.nanmean(block)
            # store directly into ctypes array
            G[i * m + j] = block_mean

#CPU times: user 1 s, sys: 348 ms, total: 1.35 s Wall time: 2.2 s
# Out:
# 10000 10000

# %%
class_lib.gridificator.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.POINTER(ctypes.c_double), ctypes.c_int, ctypes.POINTER(ctypes.c_double)]
class_lib.gridificator.restype = None
compression = 1000
G=(ctypes.c_double * int((n/compression)*(m/compression)))()
class_lib.gridificator(n,m,M,compression,G)
#G_remat = [[G[(i*m/compression) + j] for j in range(m/compression)] for i in range(n/compression)]
#show(matrix(G_remat))
n=n/compression
m=m/compression

# %%
eps = float(0.5)
round_to = 1

# %%
class_lib = ctypes.CDLL("./class_lib.so")

# %%
class_lib.max_search.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.POINTER(ctypes.c_double)]
class_lib.max_search.restype = ctypes.c_double

class_lib.slice_graph.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.POINTER(ctypes.c_double), ctypes.POINTER(ctypes.c_int)]
class_lib.slice_graph.restype = ctypes.c_int

maximum = class_lib.max_search(n,m,G)
k = int((maximum/eps) + 1)
sequence_graphs = []
sequence_connected_components={}
l = 0.0

coords={}
for x in range(n*m):
    coords[x] = (x%m, -int(x/m))
    
while l < maximum: 
    gr_con = (ctypes.c_int * (int(2*n*m*2)))()
    gr_con_len = class_lib.slice_graph(n, m, l, G, gr_con)
    gr_con_to_py = [(gr_con[2*i], gr_con[2*i+1]) for i in range(gr_con_len)]
    sequence_graphs.append(gr_con_to_py)
    sequence_connected_components[round(l,round_to)]=Graph(gr_con_to_py).connected_components_number()
    l += eps
show(sequence_connected_components)
# Out:
# {0.0: 2,
#  0.5: 5,
#  1.0: 3,
#  1.5: 4,
#  2.0: 4,
#  2.5: 4,
#  3.0: 1,
#  3.5: 1,
#  4.0: 1,
#  4.5: 1,
#  5.0: 1,
#  5.5: 1,
#  6.0: 1,
#  6.5: 1,
#  7.0: 1,
#  7.5: 1,
#  8.0: 1,
#  8.5: 1,
#  9.0: 1,
#  9.5: 1,
#  10.0: 1,
#  10.5: 0,
#  11.0: 0,
#  11.5: 0,
#  12.0: 0,
#  12.5: 0,
#  13.0: 0,
#  13.5: 0,
#  14.0: 0,
#  14.5: 0,
#  15.0: 0,
#  15.5: 0,
#  16.0: 0,
#  16.5: 0}

# %%
for a in sequence_graphs:
    Graph(a).show(pos = coords)
    print("\n\n\n")
# Out:
# Graphics object consisting of 182 graphics primitives
# Graphics object consisting of 104 graphics primitives
# Graphics object consisting of 63 graphics primitives
# Graphics object consisting of 45 graphics primitives
# Graphics object consisting of 35 graphics primitives
# Graphics object consisting of 27 graphics primitives
# Graphics object consisting of 6 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# ...

# %%
class_lib.max_search.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.POINTER(ctypes.c_double)]
class_lib.max_search.restype = ctypes.c_double

maximum = class_lib.max_search(n,m,G)
k = int((maximum/eps) + 1)

class_lib.cut.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.POINTER(ctypes.c_double),ctypes.POINTER(ctypes.c_int)]
class_lib.cut.restype = None

A = (ctypes.c_int * (n * m))()
l=0.0
A_list = []

while l < maximum: 
    class_lib.cut(n,m,l,G,A)
    A_list.append(A)
    l += eps

b=[[round(G[i*m+j],round_to) for j in range(m)] for i in range(n)]
show(matrix(b))
#
#for A in A_list:
#    b=[[A[i*m+j] for j in range(m)] for i in range(n)]
#    show(matrix(b))
#
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[23], line 4
#       1 class_lib.max_search.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.POINTER(ctypes.c_double)]
#       2 class_lib.max_search.restype = ctypes.c_double
# ----> 4 maximum = class_lib.max_search(n,m,G)
#       5 k = int((maximum/eps) + Integer(1))
#       7 class_lib.cut.argtypes = [ctypes.c_int, ctypes.c_int, ctypes.c_double, ctypes.POINTER(ctypes.c_double),ctypes.POINTER(ctypes.c_int)]
#
# ArgumentError: argument 1: TypeError: unable to convert rational 1/100 to an integer
